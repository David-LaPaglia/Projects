# %% [markdown]
# ## How are bills proposed/sponsored by Republicans in a Democratic-controlled legislature are just out-right ignored or whether they're strung along with endless amendments.

# %% [markdown]
# ### Import Necessary Modules

# %%
import requests
import json
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import re


# Turns out just because I want to use selenium doesn't make it make sense to do so for this context.

# Don't mind if there are two errors, those are due to either my connection quitting, or my keyboard interupting the program.

# %% [markdown]
# ### Scraping all(most) of the bill data from leg.colorado.gov

# %%
base_url = "https://leg.colorado.gov/bill-search?field_sessions=All&sort_bef_combine=field_bill_number%20ASC&field_chamber=All&field_bill_type=All&page="

# lists to store data
list_of_bills = []
bill_node_titles = []
bill_node_links = []
bill_desc = []
bill_last_action = []
bill_governor_signed = []
bill_sponsors_cleaned = []
bill_subjects = []
bill_session = []
bill_type = []


page_num = 0

while True:
    # Lets soupify page by page! It doesn't take as long as making get requests in ATLAS without an ethernet
    url = base_url + str(page_num)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
  
    if len(list_of_bills) > 6000: # selected this number to stop scraping.
        break 
    # create a base soup to then iterate through searching for the details!
    bill_containers = soup.find_all('div', class_='views-row')

    for container in bill_containers:
        bill_div = container.find('div', {'class': 'field-item even'})
        bill_text = bill_div.get_text(strip=True) if bill_div else None # if xxx else None is required for making array shape the correct size
        list_of_bills.append(bill_text) # it works as a data cleaning as it collects ensuring the array is the same size.
        # extract node title
        title_tag = container.find('h4', {'class': 'node__title node-title'})
        title = title_tag.get_text(strip=True) if title_tag else None
        link = title_tag.find('a')['href'] if title_tag and title_tag.find('a') else None
        bill_node_titles.append(title)
        bill_node_links.append(link)

        # extract description   
        desc_tag = container.find('div', {'class': 'field field-name-field-bill-long-title field-type-text-long field-label-hidden'})
        description = desc_tag.get_text(strip=True) if desc_tag else None
        bill_desc.append(description)

        action_tag = container.find('div', {'class': 'bill-last-action search-result-single-item'})
        last_action = action_tag.get_text(strip=True) if action_tag else None
        bill_last_action.append(last_action)
        governor_signed = 1 if last_action and 'Governor Signed' in last_action else 0
        bill_governor_signed.append(governor_signed)


        # extract sponsors
        sponsor_tag = container.find('div', {'class': 'bill-sponsors search-result-single-item'})
        sponsors = sponsor_tag.get_text(strip=True).replace("Sponsors:", "").replace("|", ", ").strip() if sponsor_tag else None
        bill_sponsors_cleaned.append(sponsors)

        # extract subject
        subject_tag = container.find('div', {'class': 'field field-name-field-subjects field-type-entityreference field-label-hidden'})
        subjects = subject_tag.get_text(strip=True) if subject_tag else None
        # add regex here or...? something to clean the lack of spaces between entries per bill
        bill_subjects.append(subjects)


        # extract session
        
        session_tag = container.find('div', {'class': 'field field-name-field-sessions field-type-entityreference field-label-hidden'})
        session = session_tag.get_text(strip=True) if desc_tag else None
        bill_session.append(session)

        # #bill-type search-result-single-item
        type_tag = container.find('div', {'class': 'bill-type search-result-single-item'})
        types = type_tag.get_text(strip=True) if desc_tag else None
        bill_type.append(types)

        if ConnectionError or KeyboardInterrupt: # bad attempt at error handling when the internet cuts out...
                df_bills = pd.DataFrame({
            'Bill Number': list_of_bills,
            'Title': bill_node_titles,
            'Link': bill_node_links,
            'Description': bill_desc,
            'Last Action': bill_last_action,
            'Governor Signed': bill_governor_signed,
            'Sponsors': bill_sponsors_cleaned,
            'Subjects':bill_subjects,
            'Session':bill_session,
            'Types':bill_type
        })

    #change the counter to load the next page
    page_num += 1


    # I love to watch my progress 
    print("Bill Numbers:", len(list_of_bills))
    print("Titles:", len(bill_node_titles))
    print("Links:", len(bill_node_links))
    print("Descriptions:", len(bill_desc))
    print("Last Actions:", len(bill_last_action))
    print("Governor Signed:", len(bill_governor_signed))
    print("Sponsors:", len(bill_subjects))
    print("Sponsors:", len(bill_sponsors_cleaned))
    print("Session:", len(bill_session))
    print("Bill Types:", len(bill_type))
    print("------------------------")

    df_bills = pd.DataFrame({
        'Bill Number': list_of_bills,
        'Title': bill_node_titles,
        'Link': bill_node_links,
        'Description': bill_desc,
        'Last Action': bill_last_action,
        'Governor Signed': bill_governor_signed,
        'Sponsors': bill_sponsors_cleaned,
        'Subjects':bill_subjects,
        'Session':bill_session,
        'Types':bill_type
    })

# clean up datetimes:

# cool tool I found for regex: https://www.regextranslator.com/
    
    df_bills['Last Action Date'] = df_bills['Last Action'].str.extract(r'(\d{1,2}/\d{1,2}/\d{4})')
    df_bills['Last Action Date'] = pd.to_datetime(df_bills['Last Action Date'], format='%m/%d/%Y')


print(df_bills)
# Out:
# Bill Numbers: 25
# Titles: 25
# Links: 25
# Descriptions: 25
# Last Actions: 25
# Governor Signed: 25
# Sponsors: 25
# Sponsors: 25
# Session: 25
# Bill Types: 25
# ------------------------
# Bill Numbers: 50
# Titles: 50
# Links: 50
# Descriptions: 50
# Last Actions: 50
# Governor Signed: 50
# Sponsors: 50
# Sponsors: 50
# Session: 50
# Bill Types: 50
# ------------------------
# Bill Numbers: 75
# Titles: 75
# Links: 75
# Descriptions: 75
# Last Actions: 75
# Governor Signed: 75
# Sponsors: 75
# Sponsors: 75
# Session: 75
# Bill Types: 75
# ------------------------
# Bill Numbers: 100
# Titles: 100
# Links: 100
# Descriptions: 100
# Last Actions: 100
# Governor Signed: 100
# Sponsors: 100
# Sponsors: 100
# Session: 100
# Bill Types: 100
# ------------------------
# Bill Numbers: 125
# Titles: 125
# Links: 125
# Descriptions: 125
# Last Actions: 125
# Governor Signed: 125
# Sponsors: 125
# Sponsors: 125
# Session: 125
# Bill Types: 125
# ------------------------
# Bill Numbers: 150
# Titles: 150
# Links: 150
# Descriptions: 150
# Last Actions: 150
# Governor Signed: 150
# Sponsors: 150
# Sponsors: 150
# Session: 150
# Bill Types: 150
# ------------------------
# Bill Numbers: 150
# Titles: 150
# Links: 150
# Descriptions: 150
# Last Actions: 150
# Governor Signed: 150
# Sponsors: 150
# Sponsors: 150
# Session: 150
# Bill Types: 150
# ------------------------
# Bill Numbers: 150
# Titles: 150
# Links: 150
# Descriptions: 150
# Last Actions: 150
# Governor Signed: 150
# Sponsors: 150
# Sponsors: 150
# Session: 150
# Bill Types: 150
# ------------------------
# Bill Numbers: 175
# Titles: 175
# Links: 175
# Titles: 550
# Links: 550
# Descriptions: 550
# Last Actions: 550
# Governor Signed: 550
# Sponsors: 550
# Sponsors: 550
# Session: 550
# Bill Types: 550
# ------------------------
# Bill Numbers: 575
# Titles: 575
# Links: 575
# Descriptions: 575
# Last Actions: 575
# Governor Signed: 575
# Sponsors: 575
# Sponsors: 575
# Session: 575
# Bill Types: 575
# ------------------------
# Bill Numbers: 600
# Titles: 600
# Links: 600
# Descriptions: 600
# Last Actions: 600
# Governor Signed: 600
# Sponsors: 600
# Sponsors: 600
# Session: 600
# Bill Types: 600
# ------------------------
# Bill Numbers: 625
# Titles: 625
# Links: 625
# Descriptions: 625
# Last Actions: 625
# Governor Signed: 625
# Sponsors: 625
# Sponsors: 625
# Session: 625
# Bill Types: 625
# ------------------------
# Bill Numbers: 650
# Titles: 650
# Links: 650
# Descriptions: 650
# Last Actions: 650
# Governor Signed: 650
# Sponsors: 650
# Sponsors: 650
# Session: 650
# Bill Types: 650
# ------------------------
# Bill Numbers: 675
# Titles: 675
# Links: 675
# Descriptions: 675
# Last Actions: 675
# Governor Signed: 675
# Sponsors: 675
# Sponsors: 675
# Session: 675
# Bill Types: 675
# ------------------------
# Bill Numbers: 700
# Titles: 700
# Links: 700
# Descriptions: 700
# Last Actions: 700
# Governor Signed: 700
# Sponsors: 700
# Sponsors: 700
# Session: 700
# Bill Types: 700
# ------------------------
# Bill Numbers: 725
# Titles: 725
# Links: 725
# Descriptions: 725
# Last Actions: 725
# Governor Signed: 725
# Sponsors: 725
# Sponsors: 725
# Session: 725
# Bill Types: 725
# ------------------------
# Bill Numbers: 750
# Titles: 750
# Links: 750
# Descriptions: 750
# Last Actions: 750
# Governor Signed: 750
# Sponsors: 750
# Sponsors: 750
# Session: 750
# Bill Types: 750
# ------------------------
# Bill Numbers: 775
# Titles: 775
# Links: 775
# Descriptions: 775
# Last Actions: 775
# Governor Signed: 775
# Sponsors: 775
# Sponsors: 775
# Session: 775
# Bill Types: 775
# ------------------------
# Bill Numbers: 800
# Titles: 800
# Links: 800
# Descriptions: 800
# Last Actions: 800
# Governor Signed: 800
# Sponsors: 800
# Sponsors: 800
# Session: 800
# Bill Types: 800
# ------------------------
# Bill Numbers: 825
# Titles: 825
# Links: 825
# Descriptions: 825
# Last Actions: 825
# Governor Signed: 825
# Sponsors: 825
# Sponsors: 825
# Session: 825
# Bill Types: 825
# ------------------------
# Bill Numbers: 850
# Titles: 850
# Links: 850
# Descriptions: 850
# Last Actions: 850
# Governor Signed: 850
# Sponsors: 850
# Sponsors: 850
# Session: 850
# Bill Types: 850
# ------------------------
# Bill Numbers: 875
# Titles: 875
# Links: 875
# Descriptions: 875
# Last Actions: 875
# Governor Signed: 875
# Sponsors: 875
# Sponsors: 875
# Session: 875
# Bill Types: 875
# ------------------------
# Bill Numbers: 900
# Titles: 900
# Links: 900
# Descriptions: 900
# Last Actions: 900
# Governor Signed: 900
# Sponsors: 900
# Sponsors: 900
# Session: 900
# Bill Types: 900
# ------------------------
# ------------------------
# Bill Numbers: 1950
# Titles: 1950
# Links: 1950
# Descriptions: 1950
# Last Actions: 1950
# Governor Signed: 1950
# Sponsors: 1950
# Sponsors: 1950
# Session: 1950
# Bill Types: 1950
# ------------------------
# Bill Numbers: 1975
# Titles: 1975
# Links: 1975
# Descriptions: 1975
# Last Actions: 1975
# Governor Signed: 1975
# Sponsors: 1975
# Sponsors: 1975
# Session: 1975
# Bill Types: 1975
# ------------------------
# Bill Numbers: 2000
# Titles: 2000
# Links: 2000
# Descriptions: 2000
# Last Actions: 2000
# Governor Signed: 2000
# Sponsors: 2000
# Sponsors: 2000
# Session: 2000
# Bill Types: 2000
# ------------------------
# Bill Numbers: 2025
# Titles: 2025
# Links: 2025
# Descriptions: 2025
# Last Actions: 2025
# Governor Signed: 2025
# Sponsors: 2025
# Sponsors: 2025
# Session: 2025
# Bill Types: 2025
# ------------------------
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:492, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492     raise new_e
#     494 # conn.request() calls http.client.*.request, not the method in
#     495 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:471, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     469     pass
# --> 471 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472 return ssl_sock
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:515, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     513     return SSLTransport(sock, ssl_context, server_hostname)
# --> 515 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:492, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492     raise new_e
#     494 # conn.request() calls http.client.*.request, not the method in
#     495 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:471, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     469     pass
# --> 471 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472 return ssl_sock
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:515, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     513     return SSLTransport(sock, ssl_context, server_hostname)
# --> 515 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 21
#      18 while True:
#      19     # Lets soupify page by page! It doesn't take as long as making get requests in ATLAS without an ethernet
#      20     url = base_url + str(page_num)
# ---> 21     response = requests.get(url)
#      22     soup = BeautifulSoup(response.content, 'html.parser')
#      25     if len(list_of_bills) > 6000: # selected this number to stop scraping.
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
df_bills
# Out:
#       Unnamed: 0 Bill Number  \
# 0              0   HB16-1001
# 1              1   HB16-1002
# 2              2   HB16-1003
# 3              3   HB16-1004
# 4              4   HB16-1005
# ...          ...         ...
# 5320        5320    SB21-118
# 5321        5321    SB21-119
# 5322        5322    SB21-120
# 5323        5323    SB21-121
# 5324        5324    SB21-122
#
#                                                   Title              Link  \
# 0     State Contract Certify Compliance With Equal P...  /bills/hb16-1001
# 1     Employee Leave Attend Child's Academic Activities  /bills/hb16-1002
# 2                      Middle Class College Savings Act  /bills/hb16-1003
# 3     Measurable Goals Deadlines Colorado Climate Ac...  /bills/hb16-1004
# 4                  Residential Precipitation Collection  /bills/hb16-1005
# ...                                                 ...               ...
# 5320   Alternative Response Mistreatment At-risk Adults   /bills/sb21-118
# 5321      Increasing Access To High-Quality Credentials   /bills/sb21-119
# 5322        Open Caption Requirement For Movie Theaters   /bills/sb21-120
# 5323             Revised Uniform Unclaimed Property Act   /bills/sb21-121
# 5324  Opiate Antagonist Bulk Purchase And Standing O...   /bills/sb21-122
#
#                                             Description  \
# 0     Concerning a requirement that a business perfo...
# 1     Concerning the ability of an employee of an em...
# 2     Concerning the state income tax deductions for...
# 3     Concerning a requirement to include measurable...
# 4     Concerning the use of rain barrels to collect ...
# ...                                                 ...
# 5320  Concerning the creation of an alternative resp...
# 5321  Concerning increasing access in high school to...
# 5322  Concerning providing open captioning in movie ...
# 5323  Concerning modifications to the "Revised Unifo...
# 5324  Concerning the bulk purchase of opiate antagon...
#
#                                             Last Action  Governor Signed  \
# 0     Last Action:03/30/2016 | Senate Committee on S...                0
# 1     Last Action:03/9/2016 | Senate Committee on St...                0
# 2     Last Action:05/5/2016 | Senate Committee on St...                0
# 3     Last Action:03/30/2016 | Senate Committee on A...                0
# 4              Last Action:05/12/2016 | Governor Signed                1
# ...                                                 ...              ...
# 5320           Last Action:06/17/2021 | Governor Signed                1
# 5321           Last Action:06/30/2021 | Governor Signed                1
# 5322  Last Action:03/10/2021 | Senate Committee on B...                0
# 5323           Last Action:04/15/2021 | Governor Signed                1
# 5324           Last Action:04/15/2021 | Governor Signed                1
#
#                                                Sponsors  \
# 0     Rep. J. Danielson, Rep. J. Buckner, Sen. J. Ul...
# 1                         Rep. J. Buckner, Sen. A. Kerr
# 2     Rep. B. Pettersen, Rep. D. Young, Sen. M. Merr...
# 3        Rep. F. Winter, Rep. J. Arndt, Sen. J. Kefalas
# 4     Rep. D. Esgar, Rep. J. Danielson, Sen. M. Merr...
# ...                                                 ...
# 5320  Sen. J. Ginal, Sen. B. Gardner, Rep. R. Pelton...
# 5321  Sen. J. Bridges, Sen. P. Lundeen, Rep. D. Esga...
# 5322  Sen. J. Ginal, Sen. J. Danielson, Rep. D. Orti...
# 5323  Sen. C. Hansen, Sen. K. Priola, Rep. R. Bocken...
# 5324                    Sen. J. Ginal, Rep. M. Froelich
#
#                                                Subjects               Session  \
# 0                    Labor & EmploymentState Government  2016 Regular Session
# 1     Education & School Finance (Pre & K-12)Labor &...  2016 Regular Session
# 2                 Fiscal Policy & TaxesHigher Education  2016 Regular Session
# 3                 EnergyNatural Resources & Environment  2016 Regular Session
# 4                                                 Water  2016 Regular Session
# ...                                                 ...                   ...
# 5320                                     Human Services  2021 Regular Session
# 5321            Education & School Finance (Pre & K-12)  2021 Regular Session
# 5322      Business & Economic DevelopmentHuman Services  2021 Regular Session
# 5323                                   State Government  2021 Regular Session
# 5324                                      Public Health  2021 Regular Session
#
#           Types Last Action Date
# 0     Type:Bill       2016-03-30
# 1     Type:Bill       2016-03-09
# 2     Type:Bill       2016-05-05
# 3     Type:Bill       2016-03-30
# 4     Type:Bill       2016-05-12
# ...         ...              ...
# 5320  Type:Bill       2021-06-17
# 5321  Type:Bill       2021-06-30
# 5322  Type:Bill       2021-03-10
# 5323  Type:Bill       2021-04-15
# 5324  Type:Bill       2021-04-15
#
# [5325 rows x 12 columns]

# %% [markdown]
# ### Run this cell to convert the dataframe to a csv

# %%
#df_bills.to_csv("co-leg-bills.csv")

# %% [markdown]
# ### Run this cell to read in said csv

# %%
df_bills = pd.read_csv('co-leg-bills.csv')
df_bills
# Out:
#       Unnamed: 0 Bill Number  \
# 0              0   HB16-1001
# 1              1   HB16-1002
# 2              2   HB16-1003
# 3              3   HB16-1004
# 4              4   HB16-1005
# ...          ...         ...
# 5320        5320    SB21-118
# 5321        5321    SB21-119
# 5322        5322    SB21-120
# 5323        5323    SB21-121
# 5324        5324    SB21-122
#
#                                                   Title              Link  \
# 0     State Contract Certify Compliance With Equal P...  /bills/hb16-1001
# 1     Employee Leave Attend Child's Academic Activities  /bills/hb16-1002
# 2                      Middle Class College Savings Act  /bills/hb16-1003
# 3     Measurable Goals Deadlines Colorado Climate Ac...  /bills/hb16-1004
# 4     Type:Bill       2016-05-12
# ...         ...              ...
# 5320  Type:Bill       2021-06-17
# 5321  Type:Bill       2021-06-30
# 5322  Type:Bill       2021-03-10
# 5323  Type:Bill       2021-04-15
# 5324  Type:Bill       2021-04-15
#
# [5325 rows x 12 columns]

# %% [markdown]
# ### Lets get more data based on bill links!

# %%
base_url = "https://leg.colorado.gov"

bill_numbers = []
bill_titles = []
bill_summaries = []
bill_sessions = []
bill_sponsors = []


for link in df_bills['Link']:
        # page content
        response = requests.get(base_url + link)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # bill number
        bill_number = soup.find('div', class_='field-item even').get_text(strip=True)
        bill_numbers.append(bill_number)
        
        # bill title
        bill_title = soup.find('h1', class_='node-title').get_text(strip=True)
        bill_titles.append(bill_title)
        
        #bill summary
        bill_summary_div = soup.find('div', class_='field field-name-field-bill-summary field-type-text-long field-label-hidden')
        bill_summary = bill_summary_div.get_text(strip=True) if bill_summary_div else None
        bill_summaries.append(bill_summary)
        
        # session information
        session_div = soup.find('div', class_='bill-session')
        session = session_div.get_text(strip=True) if session_div else None
        bill_sessions.append(session)

        # sponsor information
        sponsor_div = soup.find('div', id='block-cga-bills-bill-sponsors')
        sponsors = sponsor_div.get_text(strip=True) if sponsor_div else None # need to program in some data cleaning - names are not seperating nicely.
        bill_sponsors.append(sponsors)

        
        print(f"Processed: {bill_number}")
        bill_data_df = pd.DataFrame({
        'Bill Number': bill_numbers,
        'Title': bill_titles,
        'Summary': bill_summaries,
        'Session': bill_sessions,
        'Sponsors': bill_sponsors
    })
# Out:
# Processed: HB16-1001
# Processed: HB16-1002
# Processed: HB16-1003
# Processed: HB16-1004
# Processed: HB16-1005
# Processed: HB16-1006
# Processed: HB16-1007
# Processed: HB16-1008
# Processed: HB16-1009
# Processed: HB16-1010
# Processed: HB16-1011
# Processed: HB16-1012
# Processed: HB16-1013
# Processed: HB16-1014
# Processed: HB16-1015
# Processed: HB16-1016
# Processed: HB16-1017
# Processed: HB16-1018
# Processed: HB16-1019
# Processed: HB16-1020
# Processed: HB16-1021
# Processed: HB16-1022
# Processed: HB16-1023
# Processed: HB16-1024
# Processed: HB16-1025
# Processed: HB16-1026
# Processed: HB16-1027
# Processed: HB16-1028
# Processed: HB16-1029
# Processed: HB16-1030
# Processed: HB16-1031
# Processed: HB16-1032
# Processed: HB16-1033
# Processed: HB16-1034
# Processed: HB16-1035
# Processed: HB16-1036
# Processed: HB16-1037
# Processed: HB16-1038
# Processed: HB16-1039
# Processed: HB16-1040
# Processed: HB16-1041
# Processed: HB16-1042
# Processed: HB16-1043
# Processed: HB16-1044
# Processed: HB16-1045
# Processed: HB16-1046
# Processed: HB16-1047
# Processed: HB16-1048
# Processed: HB16-1049
# Processed: HB16-1050
# Processed: HB16-1051
# Processed: HB16-1052
# Processed: HB16-1053
# Processed: HB16-1054
# Processed: HB16-1055
# Processed: HB16-1056
# Processed: HB16-1057
# Processed: HB16-1058
# Processed: HB16-1059
# Processed: HB16-1060
# Processed: HB16-1061
# Processed: HB16-1062
# Processed: HB16-1063
# Processed: HB16-1064
# Processed: HB16-1065
# Processed: HB16-1066
# Processed: HB16-1067
# Processed: HB16-1068
# Processed: HB16-1069
# Processed: HB16-1070
# Processed: HB16-1071
# Processed: HB16-1072
# Processed: HB16-1073
# Processed: HB16-1074
# Processed: HB16-1075
# Processed: HB16-1076
# Processed: HB16-1077
# Processed: HB16-1078
# Processed: HB16-1079
# Processed: HB16-1080
# Processed: HB16-1081
# Processed: HB16-1082
# Processed: HB16-1083
# Processed: HB16-1084
# Processed: HB16-1085
# Processed: HB16-1086
# Processed: HB16-1087
# Processed: HB16-1088
# Processed: HB16-1089
# Processed: HB16-1090
# Processed: HB16-1091
# Processed: HB16-1092
# Processed: HB16-1093
# Processed: HB16-1094
# Processed: HB16-1095
# Processed: HB16-1096
# Processed: HB16-1097
# Processed: HB16-1098
# Processed: HB16-1099
# Processed: HB16-1100
# Processed: HB16-1101
# Processed: HB16-1102
# Processed: HB16-1103
# Processed: HB16-1104
# Processed: HB16-1105
# Processed: HB16-1106
# Processed: HB16-1107
# Processed: HB16-1108
# Processed: HB16-1109
# Processed: HB16-1110
# Processed: HB16-1111
# Processed: HB16-1112
# Processed: HB16-1113
# Processed: HB16-1114
# Processed: HB16-1115
# Processed: HB16-1116
# Processed: HB16-1117
# Processed: HB16-1118
# Processed: HB16-1119
# Processed: HB16-1120
# Processed: HB16-1121
# Processed: HB16-1122
# Processed: HB16-1123
# Processed: HB16-1124
# Processed: HB16-1125
# Processed: HB16-1126
# Processed: HB16-1127
# Processed: HB16-1128
# Processed: HB16-1129
# Processed: HB16-1130
# Processed: HB16-1131
# Processed: HB16-1132
# Processed: HB16-1133
# Processed: HB16-1134
# Processed: HB16-1135
# Processed: HB16-1136
# Processed: HB16-1137
# Processed: HB16-1138
# Processed: HB16-1139
# Processed: HB16-1140
# Processed: HB16-1141
# Processed: HB16-1142
# Processed: HB16-1143
# Processed: HB16-1144
# Processed: HB16-1145
# Processed: HB16-1146
# Processed: HB16-1147
# Processed: HB16-1148
# Processed: HB16-1149
# Processed: HB16-1150
# Processed: HB16-1151
# Processed: HB16-1152
# Processed: HB16-1153
# Processed: HB16-1154
# Processed: HB16-1155
# Processed: HB16-1156
# Processed: HB16-1157
# Processed: HB16-1158
# Processed: HB16-1159
# Processed: HB16-1160
# Processed: HB16-1161
# Processed: HB16-1162
# Processed: HB16-1163
# Processed: HB16-1164
# Processed: HB16-1165
# Processed: HB16-1166
# Processed: HB16-1167
# Processed: HB16-1168
# Processed: HB16-1169
# Processed: HB16-1170
# Processed: HB16-1171
# Processed: HB16-1172
# Processed: HB16-1173
# Processed: HB16-1174
# Processed: HB16-1175
# Processed: HB16-1176
# Processed: HB16-1177
# Processed: HB16-1178
# Processed: HB16-1179
# Processed: HB16-1180
# Processed: HB16-1181
# Processed: HB16-1182
# Processed: HB16-1183
# Processed: HB16-1184
# Processed: HB16-1185
# Processed: HB16-1186
# Processed: HB16-1187
# Processed: HB16-1188
# Processed: HB16-1189
# Processed: HB16-1190
# Processed: HB16-1191
# Processed: HB16-1192
# Processed: HB16-1193
# Processed: HB16-1194
# Processed: HB16-1195
# Processed: HB16-1196
# Processed: HB16-1197
# Processed: HB16-1198
# Processed: HB16-1199
# Processed: HB16-1200
# Processed: HB16-1201
# Processed: HB16-1202
# Processed: HB16-1203
# Processed: HB16-1204
# Processed: HB16-1205
# Processed: HB16-1206
# Processed: HB16-1207
# Processed: HB16-1208
# Processed: HB16-1209
# Processed: HB16-1210
# Processed: HB16-1211
# Processed: HB16-1212
# Processed: HB16-1213
# Processed: HB16-1214
# Processed: HB16-1215
# Processed: HB16-1216
# Processed: HB16-1217
# Processed: HB16-1218
# Processed: HB16-1219
# Processed: HB16-1220
# Processed: HB16-1221
# Processed: HB16-1222
# Processed: HB16-1223
# Processed: HB16-1224
# Processed: HB16-1225
# Processed: HB16-1226
# Processed: HB16-1227
# Processed: HB16-1228
# Processed: HB16-1229
# Processed: HB16-1230
# Processed: HB16-1231
# Processed: HB16-1232
# Processed: HB16-1233
# Processed: HB16-1234
# Processed: HB16-1235
# Processed: HB16-1236
# Processed: HB16-1237
# Processed: HB16-1238
# Processed: HB16-1239
# Processed: HB16-1240
# Processed: HB16-1241
# Processed: HB16-1242
# Processed: HB16-1243
# Processed: HB16-1244
# Processed: HB16-1245
# Processed: HB16-1246
# Processed: HB16-1247
# Processed: HB16-1248
# Processed: HB16-1249
# Processed: HB16-1250
# Processed: HB16-1251
# Processed: HB16-1252
# Processed: HB16-1253
# Processed: HB16-1254
# Processed: HB16-1255
# Processed: HB16-1256
# Processed: HB16-1257
# Processed: HB16-1258
# Processed: HB16-1259
# Processed: HB16-1260
# Processed: HB16-1261
# Processed: HB16-1262
# Processed: HB16-1263
# Processed: HB16-1264
# Processed: HB16-1265
# Processed: HB16-1266
# Processed: HB16-1267
# Processed: HB16-1268
# Processed: HB16-1269
# Processed: HB16-1270
# Processed: HB16-1271
# Processed: HB16-1272
# Processed: HB16-1273
# Processed: HB16-1274
# Processed: HB16-1275
# Processed: HB16-1276
# Processed: HB16-1277
# Processed: HB16-1278
# Processed: HB16-1279
# Processed: HB16-1280
# Processed: HB16-1281
# Processed: HB16-1282
# Processed: HB16-1283
# Processed: HB16-1284
# Processed: HB16-1285
# Processed: HB16-1286
# Processed: HB16-1287
# Processed: HB16-1288
# Processed: HB16-1289
# Processed: HB16-1290
# Processed: HB16-1291
# Processed: HB16-1292
# Processed: HB16-1293
# Processed: HB16-1294
# Processed: HB16-1295
# Processed: HB16-1296
# Processed: HB16-1297
# Processed: HB16-1298
# Processed: HB16-1299
# Processed: HB16-1300
# Processed: HB16-1301
# Processed: HB16-1302
# Processed: HB16-1303
# Processed: HB16-1304
# Processed: HB16-1305
# Processed: HB16-1306
# Processed: HB16-1307
# Processed: HB16-1308
# Processed: HB16-1309
# Processed: HB16-1310
# Processed: HB16-1311
# Processed: HB16-1312
# Processed: HB16-1313
# Processed: HB16-1314
# Processed: HB16-1315
# Processed: HB16-1316
# Processed: HB16-1317
# Processed: HB16-1318
# Processed: HB16-1319
# Processed: HB16-1320
# Processed: HB16-1321
# Processed: HB16-1322
# Processed: HB16-1323
# Processed: HB16-1324
# Processed: HB16-1325
# Processed: HB16-1326
# Processed: HB16-1327
# Processed: HB16-1328
# Processed: HB16-1329
# Processed: HB16-1330
# Processed: HB16-1331
# Processed: HB16-1332
# Processed: HB16-1333
# Processed: HB16-1334
# Processed: HB16-1335
# Processed: HB16-1336
# Processed: HB16-1337
# Processed: HB16-1338
# Processed: HB16-1339
# Processed: HB16-1340
# Processed: HB16-1341
# Processed: HB16-1342
# Processed: HB16-1343
# Processed: HB16-1344
# Processed: HB16-1345
# Processed: HB16-1346
# Processed: HB16-1347
# Processed: HB16-1348
# Processed: HB16-1349
# Processed: HB16-1350
# Processed: HB16-1351
# Processed: HB16-1352
# Processed: HB16-1353
# Processed: HB16-1354
# Processed: HB16-1355
# Processed: HB16-1356
# Processed: HB16-1357
# Processed: HB16-1358
# Processed: HB16-1359
# Processed: HB16-1360
# Processed: HB16-1361
# Processed: HB16-1362
# Processed: HB16-1363
# Processed: HB16-1364
# Processed: HB16-1365
# Processed: HB16-1366
# Processed: HB16-1367
# Processed: HB16-1368
# Processed: HB16-1369
# Processed: HB16-1370
# Processed: HB16-1371
# Processed: HB16-1372
# Processed: HB16-1373
# Processed: HB16-1374
# Processed: HB16-1375
# Processed: HB16-1376
# Processed: HB16-1377
# Processed: HB16-1378
# Processed: HB16-1379
# Processed: HB16-1380
# Processed: HB16-1381
# Processed: HB16-1382
# Processed: HB16-1383
# Processed: HB16-1384
# Processed: HB16-1385
# Processed: HB16-1386
# Processed: HB16-1387
# Processed: HB16-1388
# Processed: HB16-1389
# Processed: HB16-1390
# Processed: HB16-1391
# Processed: HB16-1392
# Processed: HB16-1393
# Processed: HB16-1394
# Processed: HB16-1395
# Processed: HB16-1396
# Processed: HB16-1397
# Processed: HB16-1398
# Processed: HB16-1399
# Processed: HB16-1400
# Processed: HB16-1401
# Processed: HB16-1402
# Processed: HB16-1403
# Processed: HB16-1404
# Processed: HB16-1405
# Processed: HB16-1406
# Processed: HB16-1407
# Processed: HB16-1408
# Processed: HB16-1409
# Processed: HB16-1410
# Processed: HB16-1411
# Processed: HB16-1412
# Processed: HB16-1413
# Processed: HB16-1414
# Processed: HB16-1415
# Processed: HB16-1416
# Processed: HB16-1417
# Processed: HB16-1418
# Processed: HB16-1419
# Processed: HB16-1420
# Processed: HB16-1421
# Processed: HB16-1422
# Processed: HB16-1423
# Processed: HB16-1424
# Processed: HB16-1425
# Processed: HB16-1426
# Processed: HB16-1427
# Processed: HB16-1428
# Processed: HB16-1429
# Processed: HB16-1430
# Processed: HB16-1431
# Processed: HB16-1432
# Processed: HB16-1433
# Processed: HB16-1434
# Processed: HB16-1435
# Processed: HB16-1436
# Processed: HB16-1437
# Processed: HB16-1438
# Processed: HB16-1439
# Processed: HB16-1440
# Processed: HB16-1441
# Processed: HB16-1442
# Processed: HB16-1443
# Processed: HB16-1444
# Processed: HB16-1445
# Processed: HB16-1446
# Processed: HB16-1447
# Processed: HB16-1448
# Processed: HB16-1449
# Processed: HB16-1450
# Processed: HB16-1451
# Processed: HB16-1452
# Processed: HB16-1453
# Processed: HB16-1454
# Processed: HB16-1455
# Processed: HB16-1456
# Processed: HB16-1457
# Processed: HB16-1458
# Processed: HB16-1459
# Processed: HB16-1460
# Processed: HB16-1461
# Processed: HB16-1462
# Processed: HB16-1463
# Processed: HB16-1464
# Processed: HB16-1465
# Processed: HB16-1466
# Processed: HB16-1467
# Processed: HB16-1468
# Processed: HB17-1001
# Processed: HB17-1002
# Processed: HB17-1003
# Processed: HB17-1004
# Processed: HB17-1005
# Processed: HB17-1006
# Processed: HB17-1007
# Processed: HB17-1008
# Processed: HB17-1009
# Processed: HB17-1010
# Processed: HB17-1011
# Processed: HB17-1012
# Processed: HB17-1013
# Processed: HB17-1014
# Processed: HB17-1015
# Processed: HB17-1016
# Processed: HB17-1017
# Processed: HB17-1018
# Processed: HB17-1019
# Processed: HB17-1020
# Processed: HB17-1021
# Processed: HB17-1022
# Processed: HB17-1023
# Processed: HB17-1024
# Processed: HB17-1025
# Processed: HB17-1026
# Processed: HB17-1027
# Processed: HB17-1028
# Processed: HB17-1029
# Processed: HB17-1030
# Processed: HB17-1031
# Processed: HB17-1032
# Processed: HB17-1033
# Processed: HB17-1034
# Processed: HB17-1035
# Processed: HB17-1036
# Processed: HB17-1037
# Processed: HB17-1038
# Processed: HB17-1039
# Processed: HB17-1040
# Processed: HB17-1041
# Processed: HB17-1042
# Processed: HB17-1043
# Processed: HB17-1044
# Processed: HB17-1045
# Processed: HB17-1046
# Processed: HB17-1047
# Processed: HB17-1048
# Processed: HB17-1049
# Processed: HB17-1050
# Processed: HB17-1051
# Processed: HB17-1052
# Processed: HB17-1053
# Processed: HB17-1054
# Processed: HB17-1055
# Processed: HB17-1056
# Processed: HB17-1057
# Processed: HB17-1058
# Processed: HB17-1059
# Processed: HB17-1060
# Processed: HB17-1061
# Processed: HB17-1062
# Processed: HB17-1063
# Processed: HB17-1064
# Processed: HB17-1065
# Processed: HB17-1066
# Processed: HB17-1067
# Processed: HB17-1068
# Processed: HB17-1069
# Processed: HB17-1070
# Processed: HB17-1071
# Processed: HB17-1072
# Processed: HB17-1073
# Processed: HB17-1074
# Processed: HB17-1075
# Processed: HB17-1076
# Processed: HB17-1077
# Processed: HB17-1078
# Processed: HB17-1079
# Processed: HB17-1080
# Processed: HB17-1081
# Processed: HB17-1082
# Processed: HB17-1083
# Processed: HB17-1084
# Processed: HB17-1085
# Processed: HB17-1086
# Processed: HB17-1087
# Processed: HB17-1088
# Processed: HB17-1089
# Processed: HB17-1090
# Processed: HB17-1091
# Processed: HB17-1092
# Processed: HB17-1093
# Processed: HB17-1094
# Processed: HB17-1095
# Processed: HB17-1096
# Processed: HB17-1097
# Processed: HB17-1098
# Processed: HB17-1099
# Processed: HB17-1100
# Processed: HB17-1354
# Processed: HB17-1355
# Processed: HB17-1356
# Processed: HB17-1357
# Processed: HB17-1358
# Processed: HB17-1359
# Processed: HB17-1360
# Processed: HB17-1361
# Processed: HB17-1362
# Processed: HB17-1363
# Processed: HB17-1364
# Processed: HB17-1365
# Processed: HB17-1366
# Processed: HB17-1367
# Processed: HB17-1368
# Processed: HB17-1369
# Processed: HB17-1370
# Processed: HB17-1371
# Processed: HB17-1372
# Processed: HB17-1373
# Processed: HB17-1374
# Processed: HB17-1375
# Processed: HB17B-1001
# Processed: HB18-1001
# Processed: HB18-1002
# Processed: HB18-1003
# Processed: HB18-1004
# Processed: HB18-1005
# Processed: HB18-1006
# Processed: HB18-1007
# Processed: HB18-1008
# Processed: HB18-1009
# Processed: HB18-1010
# Processed: HB18-1011
# Processed: HB18-1012
# Processed: HB18-1013
# Processed: HB18-1014
# Processed: HB18-1015
# Processed: HB18-1016
# Processed: HB18-1017
# Processed: HB18-1018
# Processed: HB18-1019
# Processed: HB18-1020
# Processed: HB18-1021
# Processed: HB18-1022
# Processed: HB18-1023
# Processed: HB18-1024
# Processed: HB18-1025
# Processed: HB18-1026
# Processed: HB18-1027
# Processed: HB18-1028
# Processed: HB18-1029
# Processed: HB18-1030
# Processed: HB18-1031
# Processed: HB18-1032
# Processed: HB18-1033
# Processed: HB18-1034
# Processed: HB18-1035
# Processed: HB18-1036
# Processed: HB18-1037
# Processed: HB18-1038
# Processed: HB18-1039
# Processed: HB18-1040
# Processed: HB18-1041
# Processed: HB18-1042
# Processed: HB18-1043
# Processed: HB18-1044
# Processed: HB18-1045
# Processed: HB18-1046
# Processed: HB18-1047
# Processed: HB18-1048
# Processed: HB18-1049
# Processed: HB18-1050
# Processed: HB18-1051
# Processed: HB18-1052
# Processed: HB18-1053
# Processed: HB18-1054
# Processed: HB18-1055
# Processed: HB18-1056
# Processed: HB18-1057
# Processed: HB18-1058
# Processed: HB18-1059
# Processed: HB18-1060
# Processed: HB18-1061
# Processed: HB18-1062
# Processed: HB18-1063
# Processed: HB18-1064
# Processed: HB18-1065
# Processed: HB18-1066
# Processed: HB18-1067
# Processed: HB18-1068
# Processed: HB18-1069
# Processed: HB18-1070
# Processed: HB18-1071
# Processed: HB18-1072
# Processed: HB18-1073
# Processed: HB18-1074
# Processed: HB18-1075
# Processed: HB18-1076
# Processed: HB18-1077
# Processed: HB18-1078
# Processed: HB18-1079
# Processed: HB18-1080
# Processed: HB18-1081
# Processed: HB18-1082
# Processed: HB18-1083
# Processed: HB18-1084
# Processed: HB18-1085
# Processed: HB18-1086
# Processed: HB18-1087
# Processed: HB18-1088
# Processed: HB18-1089
# Processed: HB18-1090
# Processed: HB18-1091
# Processed: HB18-1092
# Processed: HB18-1093
# Processed: HB18-1094
# Processed: HB18-1095
# Processed: HB18-1096
# Processed: HB18-1097
# Processed: HB18-1098
# Processed: HB18-1099
# Processed: HB18-1100
# Processed: HB18-1101
# Processed: HB18-1102
# Processed: HB18-1103
# Processed: HB18-1104
# Processed: HB18-1105
# Processed: HB18-1106
# Processed: HB18-1107
# Processed: HB18-1108
# Processed: HB18-1109
# Processed: HB18-1110
# Processed: HB18-1111
# Processed: HB18-1112
# Processed: HB18-1113
# Processed: HB18-1114
# Processed: HB18-1115
# Processed: HB18-1116
# Processed: HB18-1117
# Processed: HB18-1118
# Processed: HB18-1119
# Processed: HB18-1120
# Processed: HB18-1121
# Processed: HB18-1122
# Processed: HB18-1123
# Processed: HB18-1124
# Processed: HB18-1125
# Processed: HB18-1126
# Processed: HB18-1127
# Processed: HB18-1128
# Processed: HB18-1129
# Processed: HB18-1130
# Processed: HB18-1131
# Processed: HB18-1132
# Processed: HB18-1133
# Processed: HB18-1134
# Processed: HB18-1135
# Processed: HB18-1136
# Processed: HB18-1137
# Processed: HB18-1138
# Processed: HB18-1139
# Processed: HB18-1140
# Processed: HB18-1141
# Processed: HB18-1142
# Processed: HB18-1143
# Processed: HB18-1144
# Processed: HB18-1145
# Processed: HB18-1146
# Processed: HB18-1147
# Processed: HB18-1148
# Processed: HB18-1149
# Processed: HB18-1150
# Processed: HB18-1151
# Processed: HB18-1152
# Processed: HB18-1153
# Processed: HB18-1154
# Processed: HB18-1155
# Processed: HB18-1156
# Processed: HB18-1157
# Processed: HB18-1158
# Processed: HB18-1159
# Processed: HB18-1160
# Processed: HB18-1161
# Processed: HB18-1162
# Processed: HB18-1163
# Processed: HB18-1164
# Processed: HB18-1165
# Processed: HB18-1166
# Processed: HB18-1167
# Processed: HB18-1168
# Processed: HB18-1169
# Processed: HB18-1170
# Processed: HB18-1171
# Processed: HB18-1172
# Processed: HB18-1173
# Processed: HB18-1174
# Processed: HB18-1175
# Processed: HB18-1176
# Processed: HB18-1177
# Processed: HB18-1178
# Processed: HB18-1179
# Processed: HB18-1180
# Processed: HB18-1181
# Processed: HB18-1182
# Processed: HB18-1183
# Processed: HB18-1184
# Processed: HB18-1185
# Processed: HB18-1186
# Processed: HB18-1187
# Processed: HB18-1188
# Processed: HB18-1189
# Processed: HB18-1190
# Processed: HB18-1191
# Processed: HB18-1192
# Processed: HB18-1193
# Processed: HB18-1194
# Processed: HB18-1195
# Processed: HB18-1196
# Processed: HB18-1197
# Processed: HB18-1198
# Processed: HB18-1199
# Processed: HB18-1200
# Processed: HB18-1201
# Processed: HB18-1202
# Processed: HB18-1203
# Processed: HB18-1204
# Processed: HB18-1205
# Processed: HB18-1206
# Processed: HB18-1207
# Processed: HB18-1208
# Processed: HB18-1209
# Processed: HB18-1210
# Processed: HB18-1211
# Processed: HB18-1212
# Processed: HB18-1213
# Processed: HB18-1214
# Processed: HB18-1215
# Processed: HB18-1216
# Processed: HB18-1217
# Processed: HB18-1218
# Processed: HB18-1219
# Processed: HB18-1220
# Processed: HB18-1221
# Processed: HB18-1222
# Processed: HB18-1223
# Processed: HB18-1224
# Processed: HB18-1225
# Processed: HB18-1226
# Processed: HB18-1227
# Processed: HB18-1228
# Processed: HB18-1229
# Processed: HB18-1230
# Processed: HB18-1231
# Processed: HB18-1232
# Processed: HB18-1233
# Processed: HB18-1234
# Processed: HB18-1235
# Processed: HB18-1236
# Processed: HB18-1237
# Processed: HB18-1238
# Processed: HB18-1239
# Processed: HB18-1240
# Processed: HB18-1241
# Processed: HB18-1242
# Processed: HB18-1243
# Processed: HB18-1244
# Processed: HB18-1245
# Processed: HB18-1246
# Processed: HB18-1247
# Processed: HB18-1248
# Processed: HB18-1249
# Processed: HB18-1250
# Processed: HB18-1251
# Processed: HB18-1252
# Processed: HB18-1253
# Processed: HB18-1254
# Processed: HB18-1255
# Processed: HB18-1256
# Processed: HB18-1257
# Processed: HB18-1258
# Processed: HB18-1259
# Processed: HB18-1260
# Processed: HB18-1261
# Processed: HB18-1262
# Processed: HB18-1263
# Processed: HB18-1264
# Processed: HB18-1265
# Processed: HB18-1266
# Processed: HB18-1267
# Processed: HB18-1268
# Processed: HB18-1269
# Processed: HB18-1270
# Processed: HB18-1271
# Processed: HB18-1272
# Processed: HB18-1273
# Processed: HB18-1274
# Processed: HB18-1275
# Processed: HB18-1276
# Processed: HB18-1277
# Processed: HB18-1278
# Processed: HB18-1279
# Processed: HB18-1280
# Processed: HB18-1281
# Processed: HB18-1282
# Processed: HB18-1283
# Processed: HB18-1284
# Processed: HB18-1285
# Processed: HB18-1286
# Processed: HB18-1287
# Processed: HB18-1288
# Processed: HB18-1289
# Processed: HB18-1290
# Processed: HB18-1291
# Processed: HB18-1292
# Processed: HB18-1293
# Processed: HB18-1294
# Processed: HB18-1295
# Processed: HB18-1296
# Processed: HB18-1297
# Processed: HB18-1298
# Processed: HB18-1299
# Processed: HB18-1300
# Processed: HB18-1301
# Processed: HB18-1302
# Processed: HB18-1303
# Processed: HB18-1304
# Processed: HB18-1305
# Processed: HB18-1306
# Processed: HB18-1307
# Processed: HB18-1308
# Processed: HB18-1309
# Processed: HB18-1310
# Processed: HB18-1311
# Processed: HB18-1312
# Processed: HB18-1313
# Processed: HB18-1314
# Processed: HB18-1315
# Processed: HB18-1316
# Processed: HB18-1317
# Processed: HB18-1318
# Processed: HB18-1319
# Processed: HB18-1320
# Processed: HB18-1321
# Processed: HB18-1322
# Processed: HB18-1323
# Processed: HB18-1324
# Processed: HB18-1325
# Processed: HB18-1326
# Processed: HB18-1327
# Processed: HB18-1328
# Processed: HB18-1329
# Processed: HB18-1330
# Processed: HB18-1331
# Processed: HB18-1332
# Processed: HB18-1333
# Processed: HB18-1334
# Processed: HB18-1335
# Processed: HB18-1336
# Processed: HB18-1337
# Processed: HB18-1338
# Processed: HB18-1339
# Processed: HB18-1340
# Processed: HB18-1341
# Processed: HB18-1342
# Processed: HB18-1343
# Processed: HB18-1344
# Processed: HB18-1345
# Processed: HB18-1346
# Processed: HB18-1347
# Processed: HB18-1348
# Processed: HB18-1349
# Processed: HB18-1350
# Processed: HB18-1351
# Processed: HB18-1352
# Processed: HB18-1353
# Processed: HB18-1354
# Processed: HB18-1355
# Processed: HB18-1356
# Processed: HB18-1357
# Processed: HB18-1358
# Processed: HB18-1359
# Processed: HB18-1360
# Processed: HB18-1361
# Processed: HB18-1362
# Processed: HB18-1363
# Processed: HB18-1364
# Processed: HB18-1365
# Processed: HB18-1366
# Processed: HB18-1367
# Processed: HB18-1368
# Processed: HB18-1369
# Processed: HB18-1370
# Processed: HB18-1371
# Processed: HB18-1372
# Processed: HB18-1373
# Processed: HB18-1374
# Processed: HB18-1375
# Processed: HB18-1376
# Processed: HB18-1377
# Processed: HB18-1378
# Processed: HB18-1379
# Processed: HB18-1380
# Processed: HB18-1381
# Processed: HB18-1382
# Processed: HB18-1383
# Processed: HB18-1384
# Processed: HB18-1385
# Processed: HB18-1386
# Processed: HB18-1387
# Processed: HB18-1388
# Processed: HB18-1389
# Processed: HB18-1390
# Processed: HB18-1391
# Processed: HB18-1392
# Processed: HB18-1393
# Processed: HB18-1394
# Processed: HB18-1395
# Processed: HB18-1396
# Processed: HB18-1397
# Processed: HB18-1398
# Processed: HB18-1399
# Processed: HB18-1400
# Processed: HB18-1401
# Processed: HB18-1402
# Processed: HB18-1403
# Processed: HB18-1404
# Processed: HB18-1405
# Processed: HB18-1406
# Processed: HB18-1407
# Processed: HB18-1408
# Processed: HB18-1409
# Processed: HB18-1410
# Processed: HB18-1411
# Processed: HB18-1412
# Processed: HB18-1413
# Processed: HB18-1414
# Processed: HB18-1415
# Processed: HB18-1416
# Processed: HB18-1417
# Processed: HB18-1418
# Processed: HB18-1419
# Processed: HB18-1420
# Processed: HB18-1421
# Processed: HB18-1422
# Processed: HB18-1423
# Processed: HB18-1424
# Processed: HB18-1425
# Processed: HB18-1426
# Processed: HB18-1427
# Processed: HB18-1428
# Processed: HB18-1429
# Processed: HB18-1430
# Processed: HB18-1431
# Processed: HB18-1432
# Processed: HB18-1433
# Processed: HB18-1434
# Processed: HB18-1435
# Processed: HB18-1436
# Processed: HB18-1437
# Processed: HB18-1438
# Processed: HB18-1439
# Processed: HB18-1440
# Processed: HB18-1441
# Processed: HB19-1001
# Processed: HB19-1002
# Processed: HB19-1003
# Processed: HB19-1004
# Processed: HB19-1005
# Processed: HB19-1006
# Processed: HB19-1007
# Processed: HB19-1008
# Processed: HB19-1009
# Processed: HB19-1010
# Processed: HB19-1011
# Processed: HB19-1012
# Processed: HB19-1013
# Processed: HB19-1014
# Processed: HB19-1015
# Processed: HB19-1016
# Processed: HB19-1017
# Processed: HB19-1018
# Processed: HB19-1019
# Processed: HB19-1020
# Processed: HB19-1021
# Processed: HB19-1022
# Processed: HB19-1023
# Processed: HB19-1024
# Processed: HB19-1025
# Processed: HB19-1026
# Processed: HB19-1027
# Processed: HB19-1028
# Processed: HB19-1029
# Processed: HB19-1030
# Processed: HB19-1031
# Processed: HB19-1032
# Processed: HB19-1033
# Processed: HB19-1034
# Processed: HB19-1035
# Processed: HB19-1036
# Processed: HB19-1037
# Processed: HB19-1038
# Processed: HB19-1039
# Processed: HB19-1040
# Processed: HB19-1041
# Processed: HB19-1042
# Processed: HB19-1169
# Processed: HB19-1170
# Processed: HB19-1171
# Processed: HB19-1172
# Processed: HB19-1173
# Processed: HB19-1174
# Processed: HB19-1175
# Processed: HB19-1176
# Processed: HB19-1177
# Processed: HB19-1178
# Processed: HB19-1179
# Processed: HB19-1180
# Processed: HB19-1181
# Processed: HB19-1182
# Processed: HB19-1183
# Processed: HB19-1184
# Processed: HB19-1185
# Processed: HB19-1186
# Processed: HB19-1187
# Processed: HB19-1188
# Processed: HB19-1189
# Processed: HB19-1190
# Processed: HB19-1191
# Processed: HB19-1192
# Processed: HB19-1193
# Processed: HB19-1194
# Processed: HB19-1195
# Processed: HB19-1196
# Processed: HB19-1197
# Processed: HB19-1198
# Processed: HB19-1199
# Processed: HB19-1200
# Processed: HB19-1201
# Processed: HB19-1202
# Processed: HB19-1203
# Processed: HB19-1204
# Processed: HB19-1205
# Processed: HB19-1206
# Processed: HB19-1207
# Processed: HB19-1208
# Processed: HB19-1209
# Processed: HB19-1210
# Processed: HB19-1211
# Processed: HB19-1212
# Processed: HB19-1213
# Processed: HB19-1214
# Processed: HB19-1215
# Processed: HB19-1216
# Processed: HB19-1217
# Processed: HB19-1218
# Processed: HB19-1219
# Processed: HB19-1220
# Processed: HB19-1221
# Processed: HB19-1222
# Processed: HB19-1223
# Processed: HB19-1224
# Processed: HB19-1225
# Processed: HB19-1226
# Processed: HB19-1227
# Processed: HB19-1228
# Processed: HB19-1229
# Processed: HB19-1230
# Processed: HB19-1231
# Processed: HB19-1232
# Processed: HB19-1233
# Processed: HB19-1234
# Processed: HB19-1235
# Processed: HB19-1236
# Processed: HB19-1237
# Processed: HB19-1238
# Processed: HB19-1239
# Processed: HB19-1240
# Processed: HB19-1241
# Processed: HB19-1242
# Processed: HB19-1243
# Processed: HB19-1244
# Processed: HB19-1245
# Processed: HB19-1246
# Processed: HB19-1247
# Processed: HB19-1248
# Processed: HB19-1249
# Processed: HB19-1250
# Processed: HB19-1251
# Processed: HB19-1252
# Processed: HB19-1253
# Processed: HB19-1254
# Processed: HB19-1255
# Processed: HB19-1256
# Processed: HB19-1257
# Processed: HB19-1258
# Processed: HB19-1259
# Processed: HB19-1260
# Processed: HB19-1261
# Processed: HB19-1262
# Processed: HB19-1263
# Processed: HB19-1264
# Processed: HB19-1265
# Processed: HB19-1266
# Processed: HB19-1267
# Processed: HB19-1268
# Processed: HB19-1269
# Processed: HB19-1270
# Processed: HB19-1271
# Processed: HB19-1272
# Processed: HB19-1273
# Processed: HB19-1274
# Processed: HB19-1275
# Processed: HB19-1276
# Processed: HB19-1277
# Processed: HB19-1278
# Processed: HB19-1279
# Processed: HB19-1280
# Processed: HB19-1281
# Processed: HB19-1282
# Processed: HB19-1283
# Processed: HB19-1284
# Processed: HB19-1285
# Processed: HB19-1286
# Processed: HB19-1287
# Processed: HB19-1288
# Processed: HB19-1289
# Processed: HB19-1290
# Processed: HB19-1291
# Processed: HB19-1292
# Processed: HB19-1293
# Processed: HB19-1294
# Processed: HB19-1295
# Processed: HB19-1296
# Processed: HB19-1297
# Processed: HB19-1298
# Processed: HB19-1299
# Processed: HB19-1300
# Processed: HB19-1301
# Processed: HB19-1302
# Processed: HB19-1303
# Processed: HB19-1304
# Processed: HB19-1305
# Processed: HB19-1306
# Processed: HB19-1307
# Processed: HB19-1308
# Processed: HB19-1309
# Processed: HB19-1310
# Processed: HB19-1311
# Processed: HB19-1312
# Processed: HB19-1313
# Processed: HB19-1314
# Processed: HB19-1315
# Processed: HB19-1316
# Processed: HB19-1317
# Processed: HB19-1318
# Processed: HB19-1319
# Processed: HB19-1320
# Processed: HB19-1321
# Processed: HB19-1322
# Processed: HB19-1323
# Processed: HB19-1324
# Processed: HB19-1325
# Processed: HB19-1326
# Processed: HB19-1327
# Processed: HB19-1328
# Processed: HB19-1329
# Processed: HB19-1330
# Processed: HB19-1331
# Processed: HB19-1332
# Processed: HB19-1333
# Processed: HB19-1334
# Processed: HB19-1335
# Processed: HB20-1001
# Processed: HB20-1002
# Processed: HB20-1003
# Processed: HB20-1004
# Processed: HB20-1005
# Processed: HB20-1006
# Processed: HB20-1007
# Processed: HB20-1008
# Processed: HB20-1009
# Processed: HB20-1010
# Processed: HB20-1011
# Processed: HB20-1012
# Processed: HB20-1013
# Processed: HB20-1014
# Processed: HB20-1015
# Processed: HB20-1016
# Processed: HB20-1017
# Processed: HB20-1018
# Processed: HB20-1019
# Processed: HB20-1020
# Processed: HB20-1021
# Processed: HB20-1022
# Processed: HB20-1023
# Processed: HB20-1024
# Processed: HB20-1025
# Processed: HB20-1026
# Processed: HB20-1027
# Processed: HB20-1028
# Processed: HB20-1029
# Processed: HB20-1030
# Processed: HB20-1031
# Processed: HB20-1032
# Processed: HB20-1033
# Processed: HB20-1034
# Processed: HB20-1035
# Processed: HB20-1036
# Processed: HB20-1037
# Processed: HB20-1038
# Processed: HB20-1039
# Processed: HB20-1040
# Processed: HB20-1041
# Processed: HB20-1042
# Processed: HB20-1043
# Processed: HB20-1044
# Processed: HB20-1045
# Processed: HB20-1046
# Processed: HB20-1047
# Processed: HB20-1048
# Processed: HB20-1049
# Processed: HB20-1050
# Processed: HB20-1051
# Processed: HB20-1052
# Processed: HB20-1053
# Processed: HB20-1054
# Processed: HB20-1055
# Processed: HB20-1056
# Processed: HB20-1057
# Processed: HB20-1058
# Processed: HB20-1059
# Processed: HB20-1060
# Processed: HB20-1061
# Processed: HB20-1062
# Processed: HB20-1063
# Processed: HB20-1064
# Processed: HB20-1065
# Processed: HB20-1066
# Processed: HB20-1067
# Processed: HB20-1068
# Processed: HB20-1069
# Processed: HB20-1070
# Processed: HB20-1071
# Processed: HB20-1072
# Processed: HB20-1073
# Processed: HB20-1074
# Processed: HB20-1075
# Processed: HB20-1076
# Processed: HB20-1077
# Processed: HB20-1078
# Processed: HB20-1079
# Processed: HB20-1080
# Processed: HB20-1081
# Processed: HB20-1082
# Processed: HB20-1083
# Processed: HB20-1084
# Processed: HB20-1085
# Processed: HB20-1086
# Processed: HB20-1087
# Processed: HB20-1088
# Processed: HB20-1089
# Processed: HB20-1090
# Processed: HB20-1091
# Processed: HB20-1092
# Processed: HB20-1093
# Processed: HB20-1094
# Processed: HB20-1095
# Processed: HB20-1096
# Processed: HB20-1097
# Processed: HB20-1098
# Processed: HB20-1099
# Processed: HB20-1100
# Processed: HB20-1101
# Processed: HB20-1102
# Processed: HB20-1103
# Processed: HB20-1104
# Processed: HB20-1105
# Processed: HB20-1106
# Processed: HB20-1107
# Processed: HB20-1108
# Processed: HB20-1109
# Processed: HB20-1110
# Processed: HB20-1111
# Processed: HB20-1112
# Processed: HB20-1113
# Processed: HB20-1114
# Processed: HB20-1115
# Processed: HB20-1116
# Processed: HB20-1117
# Processed: HB20-1118
# Processed: HB20-1119
# Processed: HB20-1120
# Processed: HB20-1121
# Processed: HB20-1122
# Processed: HB20-1123
# Processed: HB20-1124
# Processed: HB20-1125
# Processed: HB20-1126
# Processed: HB20-1127
# Processed: HB20-1128
# Processed: HB20-1129
# Processed: HB20-1130
# Processed: HB20-1131
# Processed: HB20-1132
# Processed: HB20-1133
# Processed: HB20-1134
# Processed: HB20-1135
# Processed: HB20-1136
# Processed: HB20-1137
# Processed: HB20-1138
# Processed: HB20-1139
# Processed: HB20-1140
# Processed: HB20-1141
# Processed: HB20-1142
# Processed: HB20-1143
# Processed: HB20-1144
# Processed: HB20-1145
# Processed: HB20-1146
# Processed: HB20-1147
# Processed: HB20-1148
# Processed: HB20-1149
# Processed: HB20-1150
# Processed: HB20-1151
# Processed: HB20-1152
# Processed: HB20-1153
# Processed: HB20-1154
# Processed: HB20-1155
# Processed: HB20-1156
# Processed: HB20-1157
# Processed: HB20-1158
# Processed: HB20-1159
# Processed: HB20-1160
# Processed: HB20-1161
# Processed: HB20-1162
# Processed: HB20-1163
# Processed: HB20-1164
# Processed: HB20-1165
# Processed: HB20-1166
# Processed: HB20-1167
# Processed: HB20-1168
# Processed: HB20-1169
# Processed: HB20-1170
# Processed: HB20-1171
# Processed: HB20-1172
# Processed: HB20-1173
# Processed: HB20-1174
# Processed: HB20-1175
# Processed: HB20-1176
# Processed: HB20-1177
# Processed: HB20-1178
# Processed: HB20-1179
# Processed: HB20-1180
# Processed: HB20-1181
# Processed: HB20-1182
# Processed: HB20-1183
# Processed: HB20-1184
# Processed: HB20-1185
# Processed: HB20-1186
# Processed: HB20-1187
# Processed: HB20-1188
# Processed: HB20-1189
# Processed: HB20-1190
# Processed: HB20-1191
# Processed: HB20-1192
# Processed: HB20-1193
# Processed: HB20-1194
# Processed: HB20-1195
# Processed: HB20-1196
# Processed: HB20-1197
# Processed: HB20-1198
# Processed: HB20-1199
# Processed: HB20-1200
# Processed: HB20-1201
# Processed: HB20-1202
# Processed: HB20-1203
# Processed: HB20-1204
# Processed: HB20-1205
# Processed: HB20-1206
# Processed: HB20-1207
# Processed: HB20-1208
# Processed: HB20-1209
# Processed: HB20-1210
# Processed: HB20-1211
# Processed: HB20-1212
# Processed: HB20-1213
# Processed: HB20-1214
# Processed: HB20-1215
# Processed: HB20-1216
# Processed: HB20-1217
# Processed: HB20-1218
# Processed: HB20-1219
# Processed: HB20-1220
# Processed: HB20-1221
# Processed: HB20-1222
# Processed: HB20-1223
# Processed: HB20-1224
# Processed: HB20-1225
# Processed: HB20-1226
# Processed: HB20-1227
# Processed: HB20-1228
# Processed: HB20-1229
# Processed: HB20-1230
# Processed: HB20-1231
# Processed: HB20-1232
# Processed: HB20-1233
# Processed: HB20-1234
# Processed: HB20-1235
# Processed: HB20-1236
# Processed: HB20-1237
# Processed: HB20-1238
# Processed: HB20-1239
# Processed: HB20-1240
# Processed: HB20-1241
# Processed: HB20-1242
# Processed: HB20-1243
# Processed: HB20-1244
# Processed: HB20-1245
# Processed: HB20-1246
# Processed: HB20-1247
# Processed: HB20-1248
# Processed: HB20-1249
# Processed: HB20-1250
# Processed: HB20-1251
# Processed: HB20-1252
# Processed: HB20-1253
# Processed: HB20-1254
# Processed: HB20-1255
# Processed: HB20-1256
# Processed: HB20-1257
# Processed: HB20-1258
# Processed: HB20-1259
# Processed: HB20-1260
# Processed: HB20-1261
# Processed: HB20-1262
# Processed: HB20-1263
# Processed: HB20-1264
# Processed: HB20-1265
# Processed: HB20-1266
# Processed: HB20-1267
# Processed: HB20-1268
# Processed: HB20-1269
# Processed: HB20-1270
# Processed: HB20-1271
# Processed: HB20-1272
# Processed: HB20-1273
# Processed: HB20-1274
# Processed: HB20-1275
# Processed: HB20-1276
# Processed: HB20-1277
# Processed: HB20-1278
# Processed: HB20-1279
# Processed: HB20-1280
# Processed: HB20-1281
# Processed: HB20-1282
# Processed: HB20-1283
# Processed: HB20-1284
# Processed: HB20-1285
# Processed: HB20-1286
# Processed: HB20-1287
# Processed: HB20-1288
# Processed: HB20-1289
# Processed: HB20-1290
# Processed: HB20-1291
# Processed: HB20-1292
# Processed: HB20-1293
# Processed: HB20-1294
# Processed: HB20-1295
# Processed: HB20-1296
# Processed: HB20-1297
# Processed: HB20-1298
# Processed: HB20-1299
# Processed: HB20-1300
# Processed: HB20-1301
# Processed: HB20-1302
# Processed: HB20-1303
# Processed: HB20-1304
# Processed: HB20-1305
# Processed: HB20-1306
# Processed: HB20-1307
# Processed: HB20-1308
# Processed: HB20-1309
# Processed: HB20-1310
# Processed: HB20-1311
# Processed: HB20-1312
# Processed: HB20-1313
# Processed: HB20-1314
# Processed: HB20-1315
# Processed: HB20-1316
# Processed: HB20-1317
# Processed: HB20-1318
# Processed: HB20-1319
# Processed: HB20-1320
# Processed: HB20-1321
# Processed: HB20-1322
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 12
#       7 bill_sponsors = []
#      10 for link in df_bills['Link']:
#      11         # page content
# ---> 12         response = requests.get(base_url + link)
#      13         response.raise_for_status()
#      14         soup = BeautifulSoup(response.content, 'html.parser')
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#bill_data_df.to_csv("bill_data_df(Sponsors).csv")
bill_data_df = pd.read_csv('bill_data_df(Sponsors)')
bill_data_df
# Out:
#      Bill Number                                              Title  \
# 0      HB16-1001  State Contract Certify Compliance With Equal P...
# 1      HB16-1002  Employee Leave Attend Child's Academic Activities
# 2      HB16-1003                   Middle Class College Savings Act
# 3      HB16-1004  Measurable Goals Deadlines Colorado Climate Ac...
# 4      HB16-1005               Residential Precipitation Collection
# ...          ...                                                ...
# 1937   HB20-1318                      Standards For Recording Plats
# 1938   HB20-1319        Prohibit Sale Of Flavored Nicotine Products
# 1939   HB20-1320          Off-highway Vehicle Certificates Of Title
# 1940   HB20-1321  State Bid Preference For EPA Environmental Pro...
# 1941   HB20-1322          Public Participation Property Tax Manuals
#
#                                                 Summary  \
# 0     The bill requires a business that bids for a c...
# 1     In 2009, the general assembly enacted the 'Par...
# 2     For purposes of calculating a taxpayer's Color...
# 3     The bill requires:The state climate action pla...
# 4     Section 1 of the act allows the collection of ...
# ...                                                 ...
# 1937  The act allows county clerk and recorders to r...
# 1938  On and after September 1, 2020, the bill prohi...
# 1939  Current law requires an off-highway vehicle to...
# 1940  The SmartWay transport partnership program of ...
# 1941  The property tax administrator is required by ...
#
#                            Session  \
# 0     Session:2016 Regular Session
# 1     Session:2016 Regular Session
# 2     Session:2016 Regular Session
# 3     Session:2016 Regular Session
# 4     Session:2016 Regular Session
# ...                            ...
# 1937  Session:2020 Regular Session
# 1938  Session:2020 Regular Session
# 1939  Session:2020 Regular Session
# 1940  Session:2020 Regular Session
# 1941  Session:2020 Regular Session
#
#                                                Sponsors
# 0     Prime SponsorsRepresentativeJessie DanielsonRe...
# 1     Prime SponsorsRepresentativeJanet BucknerSenat...
# 2     Prime SponsorsRepresentativeBrittany Pettersen...
# 3     Prime SponsorsRepresentativeFaith WinterRepres...
# 4     Prime SponsorsRepresentativeDaneya EsgarRepres...
# ...                                                 ...
# 1937  Prime SponsorsRepresentativeShannon BirdRepres...
# 1938  Prime SponsorsRepresentativeYadira CaraveoRepr...
# 1939  Prime SponsorsRepresentativeKevin Van WinkleRe...
# 1940          Prime SponsorsRepresentativeBri Buentello
# 1941  Prime SponsorsRepresentativeColin LarsonRepres...
#
# [1942 rows x 5 columns]

# %% [markdown]
# ### Importing CSV data from EXCEL

# %%
co_stats_df = pd.read_csv('20241101_statistics.csv')
gender_status_stats_df = pd.read_csv('20241101gender_status_statistics.csv')

# %%
co_stats_df
# Out:
#    Total Registered Voters by Party & Status \nas of 00:17 on 11/01/2024  \
# 0                            Active registered voters
# 1                                              County
# 2                                               Adams
# 3                                             Alamosa
# 4                                            Arapahoe
# ..                                                ...
# 63                                         Washington
# 64                                               Weld
# 65                                               Yuma
# 66                                              Total
# 67                                   end of worksheet
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         ACN        APV        CTR        DEM        FWD        GRN
# 2       1,308        809        236     91,779         22        627
# 3          60         24          2      2,745          0         20
# 4       1,248        701        300    125,374         29        853
# ..        ...        ...        ...        ...        ...        ...
# 63         14          2          1        195          0          2
# 64        941        360        141     42,146          9        379
# 65         21          3          3        519          0          3
# 66     11,746      4,990      3,200  1,046,870        248      8,741
# 67        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1         LBR        NOL        REP  ...         FWD         GRN         LBR
# 2       2,897      2,236     59,911  ...           0          10           9
# 3          75         52      2,731  ...           0           0           0
# 4       3,829      2,297     84,239  ...           2          10          12
# ..        ...        ...        ...  ...         ...         ...         ...
# 63         15          6      2,134  ...           0           0           0
# 64      2,269      1,327     71,752  ...           0           2           6
# 65         35         12      2,974  ...           0           0           0
# 66     37,756     20,925    936,583  ...           2          68         131
# 67        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#    Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37   Unnamed: 38 Unnamed: 39  \
# 0          NaN         NaN         NaN         NaN           NaN         All
# 1          NOL         REP         UAF         UNI  Prereg Total      County
# 2           78         330       5,414           2         6,110       Adams
# 3            1          11         168           0           185     Alamosa
# 4          118         520       6,603           0         7,839    Arapahoe
# ..         ...         ...         ...         ...           ...         ...
# 63           0          22          26           0            48  Washington
# 64          56         557       3,967           1         4,775        Weld
# 65           0          36         120           0           157        Yuma
# 66       1,060       6,348      55,172          15        67,054       Total
# 67         NaN         NaN         NaN         NaN           NaN         NaN
#
#     Unnamed: 40
# 0           NaN
# 1   Grand Total
# 2       360,518
# 3        11,988
# 4       487,712
# ..          ...
# 63        3,699
# 64      261,220
# 65        6,494
# 66    4,622,650
# 67          NaN
#
# [68 rows x 41 columns]

# %%
gender_status_stats_df
# Out:
#    Total Registered Voters by Status\nas of 00:17 on 11/01/2024 Unnamed: 1  \
# 0                           Active Registered Voters                   NaN
# 1                                              County               Female
# 2                                               Adams              160,523
# 3                                             Alamosa                5,258
# 4                                            Arapahoe              216,316
# ..                                                ...                  ...
# 63                                         Washington                1,586
# 64                                               Weld              116,441
# 65                                               Yuma                2,960
# 66                                              Total            2,028,014
# 67                                   end of worksheet                  NaN
#
#    Unnamed: 2     Unnamed: 3 Unnamed: 4    Unnamed: 5  \
# 0         NaN            NaN        NaN           NaN
# 1        Male  Not Disclosed          X  Active Total
# 2     155,043          1,295      1,602       318,463
# 3       4,917             17         52        10,244
# 4     204,844          1,711      1,462       424,333
# ..        ...            ...        ...           ...
# 63      1,722              3          6         3,317
# 64    112,818            771        602       230,632
# 65      2,857             11         13         5,841
# 66  1,958,250         15,746     16,907     4,018,917
# 67        NaN            NaN        NaN           NaN
#
#                      Unnamed: 6 Unnamed: 7 Unnamed: 8     Unnamed: 9  ...  \
# 0   Inactive Registered Voters         NaN        NaN            NaN  ...
# 1                        County     Female       Male  Not Disclosed  ...
# 2                         Adams     17,161     18,127             26  ...
# 3                       Alamosa        753        780              0  ...
# 4                      Arapahoe     26,894     28,104             18  ...
# ..                          ...        ...        ...            ...  ...
# 63                   Washington        166        159              1  ...
# 64                         Weld     12,136     13,451              9  ...
# 65                         Yuma        240        250              0  ...
# 66                        Total    252,087    273,039            276  ...
# 67                          NaN        NaN        NaN            NaN  ...
#
#    Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 63         NaN         NaN         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...
# 63         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN
#
# [68 rows x 30 columns]
